# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Meg M**
#  <br>International diplomat, ethical technologies

# %% [markdown]
# *I am interested in data science because it is the underpinning of AI/ML technologies, which are disrupting institutions and society. I need a fundamental understanding of this technoogy if I am to play a role in shaping the safety and sustainability of technology in the future.*

# %% [markdown]
# ### The code below should output a heart emoji and welcoming message.

# %%
print(emoji.emojize('Hi there! :revolving_hearts:'))
# Out:
# Hi there! 💞

# %% [markdown]
# ## Hortizontal line: <br>
# ***
#
# ## Bulleted list:<br>
# - one
# - two
# - three <br><br>
#
# ## Hyperlink:<br>
# <a href="https://google.com">Google</a>" <br><br>
# ## Table: <br>
# | header 1 | header 2 |  header 3 |
# | ------ | ------ | ------ |
# | cell a | cell b | cell c |
